# %%
'''
Declaring the object game
'''
#import clear_screen
#from clear_screen import clear
import random

class Game_Black_Jack():
    #General Attributes this will be useful, for the entire game
    
    deck_cards=[]
    nlst=deck_cards.copy
    winner_21=21
    sum_cards=0
    
    
    # A T T R I B U T E S
    #Initializing the object Game Black Jack
    #Attributes that must contain the game,player,dealer,
    
    def __init__(self,player,dealer):
        self.player=player
        self.dealer=dealer
        
        
    # S P E C I A L  M E T H O D S    
        
    def __str__(self):
        
        return('Game Started!!!')
        
        
    # M E T H O D S 
    #Function for the Attributes, class of sub objects.
    
    #To print at the begining 
    def welcome(self):
        return('H e l l o  !!!\nWelcome to the game,\n')

    #To ask the player for a Game
    def player_game(self):
        y=(input('Hello!!!!, welcome to the game\nDo you want to play,\nentry yes ')).lower()
        while y != 'yes'or y !='no' :
            print('what?, try again!!!')
            #y=(input('Do you want to play,\nentry yes ')).lower()
            if y == 'no':
                return('Thanks')
                break
            if y == 'yes':
                return('Your Account has been Created suceesfully')
            break
            continue


        
        
    #to determinate who is the turn in the game
    def turns(self):
        
        if self.player_game()=='Your Account has been Created suceesfully':
            return('ok')
        elif self.player_game()=='Thanks':
            return('oh')
        
    #to determinate who is the winner in the game
    def winner(self):
        if self.winner_21 == self.sum_cards:
            print('you got 21')
        else :
            print('nice try')
               
        
player='player'
dealer='dealer'
bjck=Game_Black_Jack(player,dealer)



    
                    #P L A Y E R      C L A S S 
'''

Declaring the object player

'''            
class Player():
     
    #General Attributes that will be use in the curse of the game

    
    
    #Initializing the Object Player
    
    def __init__(self,sum_cards,balance,bet):
        self.sum_cards=sum_cards
        self.balance=balance
        self.bet=bet
        
    # S P E C I A L     M E T H O D S    P L A Y E R      C L A S S 
        
    def __str__(self):
        return 'Player  Account Created'
        
   
    # M E T H O D S 
    def balance_m(self):
        self.balance=self.balance
        if bjck.__str__()=='Game Started!!!' and self.balance ==0 and bjck.turns()=='ok':      
            if self.balance ==0 or self.balance< 0:
                dep=input('your Balance is empty,please make a Deposit\nto make a bet,entry the amount\n:')
                self.balance=self.balance+int(dep)
                if int(dep)>0:
                    print('Deposit Accepted you can continue\n')
                else:
                    dep=input('please entry mayor amount\n:')
                    self.balance=self.balance+int(dep)
        if self.balance < 0 :
            dep=input('your Balance is empty,please make a Deposit\nto make a bet,entry the amount\n:')
            self.balance=self.balance+int(dep)
        elif bjck.turns()== 'oh':
            return('See you next time!!')
        
    
        print('your current balance is {}'.format(self.balance))
        return self.balance
    
    def bet_m(self):
        self.balance=self.balance
        self.bet=self.bet
        if self.balance_m() > 0 and self.bet==0 and bjck.turns()=='ok':
            self.bet=int(input('to receive your cards and start the game, please make a bet\n:'))
            if self.bet>self.balance:
                self.bet=int(input("Looks like you don't have enough money, please entry an amount less than {}:".format(self.balance)))
            else:
                print("your Bet for the amount {} has been accepted!!\nG o o d     l u c k !!!".format(self.bet))
            return self.bet
        elif self.balance >0 and self.bet>0 and bjck.turns()=='ok':
            self.bet=int(input('to receive your second card confirm your bet:\n'))
            return self.bet
        else:
            return('See you next time!!')
        
        
    
        
sum_cards=0
balance=0
bet=0
ply=Player(sum_cards,balance,bet)        


#!!!!!after this I have to create the dealer to be able to make the repartition because the dealer needs to have one card visible.




            # D E A L E R       C L A S S

'''
Declaring the object Dealer
'''
class Dealer():
    
    #General Attributes for the daler
    
    
    
    #Initilizing the Object Dealer
    
    def __init__(self,sum_cards,money,dealer_cards):
        self.sum_cards=sum_cards
        self.money=money
        self.dealer_cards=dealer_cards
        
    
    # S P E C I A L     M E T H O D S 
    
    def __str__(self):
        if ply.bet_m()>0:
            return('Dealer Playing')
        else:
            return('No Game Initialized')

    
    # M E T H O D S 
    
    def deal_cards(self):
        #dl.dealer
        if dl.sum_cards[0]>0:
            dl.dealer_cards=sum(dl.sum_cards)
            return dl.dealer_cards
    
    
    
    
    def dealer21(self):
        if dl.sum_cards[0]>0:
            dl.dealer_cards=sum(dl.sum_cards)
            #this first lines to convert if the delaer has received 1 and 10 convert the one in eleven, before pick  another card
            if dl.sum_cards[0]==1 and dl.sum_cards[1]==10:
                dl.sum_cards[0]==11
                dl.dealer_cards=sum(dl.sum_cards)
            elif dl.sum_cards[0]==10 and dl.sum_cards[1]==1:
                dl.sum_cards[1]==11
                dl.dealer_cards=sum(dl.sum_cards)
            elif dl.sum_cards[0]==1 or dl.sum_cards[1]==1:
                dl.sum_cards[0]=11
                dl.sum_cards[1]=11
                dl.dealer_cards=sum(dl.sum_cards)
        return dl.dealer_cards
    
    
    
sum_cards=[]
money=10000
dealer_cards=0

dl=Dealer(sum_cards,money,dealer_cards)
        
        

#all of the procedures above are in sequence if there is balance then ask for bet if there
#is a bet mayor then zero ask for a bet, if theres is a bet the dealer is playing
#that needs to be the way of work
#


                # C L A S S   D E C K 

'''
Declaring the Class Deck
'''

class Deck(Game_Black_Jack):
    #General Attributes of the Deck
    cards=[('TWO',2,'♥'),('THREE',3,'♥'),('FOUR',4,'♥'),('FIVE',5,'♥'),('SIX',6,'♥'),
       ('SEVEN',7,'♥'),('EIGHT',8,'♥'),('NINE',9,'♥'),('TEN',10,'♥'),('JACK',10,'♥'),
       ('QUEEN',10,'♥'),('KING',10,'♥'),('AS',1,'♥'),('TWO',2,'♦'),('THREE',3,'♦'),
       ('FOUR',4,'♦'),('FIVE',5,'♦'),('SIX',6,'♦'),('SEVEN',7,'♦'),('EIGHT',8,'♦'),
       ('NINE',9,'♦'),('TEN',10,'♦'),('JACK',10,'♦'),('QUEEN',10,'♦'),('KING',10,'♦'),
       ('AS',1,'♦'),('TWO','♣',2),('THREE',3,'♣'),('FOUR',4,'♣'),('FIVE',5,'♣'),
       ('SIX',6,'♣'),('SEVEN',7,'♣'),('EIGHT',8,'♣'),('NINE',9,'♣'),('TEN',10,'♣'),
       ('JACK',10,'♣'),('QUEEN',10,'♣'),('KING',10,'♣'),('AS',1,'♣'),('TWO',2,'♠'),
       ('THREE',3,'♠'),('FOUR',4,'♠'),('FIVE',5,'♠'),('SIX',6,'♠'),('SEVEN',7,'♠'),
       ('EIGHT',8,'♠'),('NINE',9,'♠'),('TEN',10,'♠'),('JACK',10,'♠'),('QUEEN',10,'♠'),
       ('KING',10,'♠'),('AS',1,'♠')]
    nlst=cards
    bjck.player=0
    ply.sum_cards=0
    #Initializing the Class Deck
    def __init__(self,name_cards,value_cards,symbol_card):
        self.name_cards=name_cards
        self.value_cards=value_cards
        self.symbol_cards=symbol_cards
        
    
    
    # S P E C I A L      M E T H O D S  
    
    def __str__(self):
        print(dk.name_cards,dk.value_cards,' ',dk.symbol_cards,' \n'*3,dk.symbol_cards*dk.value_cards,' \n'*3,dk.symbol_cards,' ',dk.value_cards,dk.name_cards)
        return('Object Deck Created, sucessfully')
        
        
        

    # M E T H O D S
    
    #THIS PICK UP ANY CARD OF THE DECK
    def random_card_m(self,random):
        import random
        self.random=random
        random=random.randint(0,len(dk.nlst)-1)
        return(random)
    
    def indx_m(self):
        if dk.random_card_m() in self.nlst:
            true='true'
        return(dk.nlst.index(dk.random_card_m()))
        
        
       #this procedure is to repart the card at the dealer
    def partition_m(self):
        bjck.player=0
        if dl.__str__() == 'Dealer Playing':
            #dl.sum_cards=[]
            bjck.player=0
            dl.sum_cards=dl.sum_cards
            print(dk)
            rdn1=(dk.cards.index(dk.cards[random]))#index of the card selected
            bjck.dealer=dk.cards[rdn1][1]
            
            print('The visible card for the Dealer')#thisis the correct
            
            dk.nlst.remove(dk.nlst[rdn1])
            dl.sum_cards.append(bjck.dealer)
            return bjck.dealer
        elif dl.__str__() =='No Game Initialized':
            return'No Game Initialized'
        
           
           
    def turn_player_m(self):
        bjck.player=0
        if dk.partition_m()>0:
            #bjck.player=0
            #card one
            def card_one():
                return dk.random_card_m(random)
            rdn1=dk.nlst[card_one()]
            print(rdn1[0],rdn1[1],' \n'*3,rdn1[2]*rdn1[1],' \n'*3,' ',rdn1[1],rdn1[0])
            bjck.player=rdn1[1]
            #this procedure to remove
            dk.nlst.remove(rdn1)
            print('this is your  card')
            return bjck.player
        elif dk.partition_m()=='No Game Initialized':
            return('See You Next Time')
    
    
    def sum_cards_m(self):

        if dk.turn_player_m()>0:
            if bjck.player == 1:
                val_as=int(input('Do you prefer value 1 or 11 for your AS:'))
                ply.sum_cards=ply.sum_cards+val_as
            else:
                ply.sum_cards=ply.sum_cards+bjck.player
            print('The sums of your cards:{}'.format(ply.sum_cards))
            return ply.sum_cards
        elif dk.turn_player_m()== 'See You Next Time':
            return 'See You Next Time'
    
    
    def scnd_card_m(self):
        bjck.player=0
        if dk.sum_cards_m()>0:
            def two():
                return dk.sum_cards_m()
            bjck.player=two()
        elif dk.sum_cards_m()=='See You Next Time':
            return 'See You Next Time'
        else:
            bjck.player=bjck.player  
        return bjck.player

    
    #this function is to Verify a Winner
    def winners_m(self):
        dl.dealer21()
        dl.dealer_cards=dl.dealer21()
        if dl.dealer_cards > bjck.player and dl.dealer_cards <=21 and bjck.player!=21:
            print('sorry, nice game,you have lost')
            ply.balance=ply.balance-ply.bet
            print('your current balance is {}'.format(ply.balance))
            bjck.winner_21=True
            bjck.player=0
            ply.sum_cards=0
        if bjck.player> dl.dealer_cards and bjck.player<=21 and dl.dealer_cards!=21:
            print('you have won!!!, Congratulation')
            ply.balance=ply.balance +(ply.bet*2)
            print('your current balance is {}'.format(ply.balance))
            bjck.player=0
            ply.sum_cards=0
            bjck.winner_21=True
        else:
            bjck.winner_21=False
        
        return bjck.winner_21
        
    
    
    #to pick the card for the dealer
    def hitts_m(self):

    #if the delaer value is less than 21 then pick another card
        if dl.dealer21()<21:
            while dl.dealer_cards!=21:
                print('Turn of Dealer')
                dk.nlst=dk.nlst
                def hitagain():
                    return(dk.random_card_m(random))

                rdn1=dk.nlst[hitagain()]
                print(rdn1[0],rdn1[1],' \n'*3,rdn1[2]*rdn1[1],' \n'*3,' ',rdn1[1],rdn1[0])
                print('Delaer card')
                dl.sum_cards.append(rdn1[1])
                dl.dealer21()
                if rdn1[1]== 1 and dl.dealer_cards == 10:
                    dl.dealer_cards=dl.dealer_cards+11
                else:
                    dl.dealer_cards=dl.dealer_cards+rdn1[1]
                dk.nlst.remove(rdn1)
                dk.winners_m()
                if dl.dealer_cards>21:
                    dk.winners_m()
                    
                    break
                        #break
        return dl.dealer_cards

    #this function is to make the player to make a hit or stay

    def hitting_m(self):
        if dk.scnd_card_m()>0:#this is the way to connect with pass methods  
            hit_cards=input('Do you want to hit or stay, please provide your answer:\n').lower()
            dl.dealer21()
            dl.dealer_cards=dl.dealer21()
            print(dl.dealer_cards)
            bjck.player=bjck.player
            while  hit_cards == 'hit' or hit_cards != 'stay' :
                #hit_cards=input('Do you want to hit or stay, please provide your answer:\n').lower()
                if  hit_cards == 'stay'  :
                    print('Turn of Dealer')
                    bjck.player=0
                    bjck.dealer=dk.hitts_m()
                    break 
                
                if hit_cards == 'hit' and  bjck.player < 21 and dl.dealer_cards !=21 :
                    dk.nlst=dk.nlst
                    
                    def new_ran(random):
                        return dk.random_card_m(random)

                    
                    rdn1=self.nlst[new_ran(random)]
                    print(rdn1[0],rdn1[1],' \n'*3,rdn1[2]*rdn1[1],' \n'*3,' ',rdn1[1],rdn1[0])
                    bjck.player=bjck.player+rdn1[1]
                    print(bjck.player)
                    def eraser():
                        dk.nlst.remove(rdn1)
                        return dk.nlst
                    dk.nlst=eraser()
                    if  bjck.player>21:
                        dk.winners_m()
                        print('sorry, nice game,you have lost')
                        ply.balance=ply.balance-ply.bet
                        print('your current balance is {}'.format(ply.balance))
                        bjck.player=0
                        ply.sum_cards=0
                        break
                    else:
                        hit_cards=input('Do you want to hit or stay, please provide your answer:\n').lower()
            #bjck.player=bjck.player   
            #Dealer Turn
            if  hit_cards == 'stay' :
                print('hey')
                #print(dl.dealer_cards<21)
                print(dl.dealer_cards)
                dl.dealer21()
                if dl.dealer_cards < 21:
                    def deal():
                        return dk.hitts_m()
                    deal()
                if dl.dealer_cards>21:
                    print('dealer is mayor 21')
                    if dl.dealer_cards> 21 and dl.dealer_cards > bjck.player:
                    
                        print('you have won!!!, Congratulation')
                        ply.balance=ply.balance +(ply.bet*2)
                        print('your current balance is {}'.format(ply.balance))
                        bjck.player=0
                        ply.sum_cards=0
            dk.winners_m()    
            print(dk.winners_m())
                
            #the comment  is the way to return the value the cards for the delaer
            print('Dealer Turn,value card:{}'.format(dl.sum_cards[0]))
            print(dl.sum_cards)#this list contain the two cards for the dealer
            print(sum(dl.sum_cards))#this is the sum of the dealer cards
            print('The sums of your cards:{}'.format(bjck.player))
            bjck.player=0
            #dk.winners_m()
            return bjck.player      
        elif dk.scnd_card_m()== 'See You Next Time':
            return 'See You Next Time'
        
    
    def play_again_m(self):
        try:
            pl=input('Do you want to play again?, yes or no: ').lower()
            while pl!= 'no' and dl.__str__!='No Game Initialized':
                #to Restore the values to Zero to start again
                ply.bet=0
                bjck.player=0
                dl.dealer_cards = 0
                dk.nlst=cards
                bjck.dealer='dealer'
                dl.sum_cards=[]
                ply.sum_cars=0
                dk.hitting_m()
                

                
                if pl=='no' and dl.__str__=='No Game Initialized':
                    break
                continue
        except:
            print ('Thanks for playing')

    
    
    
  #General Definitions

cards=[('TWO',2,'♥'),('THREE',3,'♥'),('FOUR',4,'♥'),('FIVE',5,'♥'),('SIX',6,'♥'),
       ('SEVEN',7,'♥'),('EIGHT',8,'♥'),('NINE',9,'♥'),('TEN',10,'♥'),('JACK',10,'♥'),
       ('QUEEN',10,'♥'),('KING',10,'♥'),('AS',1,'♥'),('TWO',2,'♦'),('THREE',3,'♦'),
       ('FOUR',4,'♦'),('FIVE',5,'♦'),('SIX',6,'♦'),('SEVEN',7,'♦'),('EIGHT',8,'♦'),
       ('NINE',9,'♦'),('TEN',10,'♦'),('JACK',10,'♦'),('QUEEN',10,'♦'),('KING',10,'♦'),
       ('AS',1,'♦'),('TWO','♣',2),('THREE',3,'♣'),('FOUR',4,'♣'),('FIVE',5,'♣'),
       ('SIX',6,'♣'),('SEVEN',7,'♣'),('EIGHT',8,'♣'),('NINE',9,'♣'),('TEN',10,'♣'),
       ('JACK',10,'♣'),('QUEEN',10,'♣'),('KING',10,'♣'),('AS',1,'♣'),('TWO',2,'♠'),
       ('THREE',3,'♠'),('FOUR',4,'♠'),('FIVE',5,'♠'),('SIX',6,'♠'),('SEVEN',7,'♠'),
       ('EIGHT',8,'♠'),('NINE',9,'♠'),('TEN',10,'♠'),('JACK',10,'♠'),('QUEEN',10,'♠'),
       ('KING',10,'♠'),('AS',1,'♠')]

random=random.randint(0,len(cards)-1)
name_cards=cards[random][0]
value_cards=cards[random][1]
symbol_cards=cards[random][2]
dk=Deck(name_cards,value_cards,symbol_cards)


#print(dk.hitting_m())
#print(dk.winners_m())
#print(dk.hitts_m())

print(dk.play_again_m())
# Out:
# Do you want to play again?, yes or no: yes
# Hello!!!!, welcome to the game
# Do you want to play,
# entry yes yes
# what?, try again!!!
# your Balance is empty,please make a Deposit
# to make a bet,entry the amount
# :500
# Deposit Accepted you can continue
#
# Hello!!!!, welcome to the game
# Do you want to play,
# entry yes yes
# what?, try again!!!
# your current balance is 500
# Hello!!!!, welcome to the game
# Do you want to play,
# entry yes yes
# what?, try again!!!
# to receive your cards and start the game, please make a bet
# :300
# your Bet for the amount 300 has been accepted!!
# G o o d     l u c k !!!
# SEVEN 7   ♥
#
#
#  ♥♥♥♥♥♥♥
#
#
#  ♥   7 SEVEN
# Object Deck Created, sucessfully
# The visible card for the Dealer
# FIVE 5
#
#
#  ♠♠♠♠♠
#
#
#    5 FIVE
# this is your  card
# The sums of your cards:5
# Hello!!!!, welcome to the game
# Do you want to play,
# entry yes yes
# what?, try again!!!
# your current balance is 500
# Hello!!!!, welcome to the game
# ...
